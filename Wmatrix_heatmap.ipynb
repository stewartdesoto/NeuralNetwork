# %%
import numpy as np
# %matplotlib inline

# %%
W=np.loadtxt('Wmatrix')

# %%
W.shape
# Out:
# (24, 15)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
heatmap = plt.pcolor(W)
plt.xlabel('Innput Feature')
plt.ylabel('Hidden Unit')
plt.title('First Layer Matrix Weight Coefficients')
plt.colorbar(heatmap)
plt.savefig('Wmatrix_heatmap.png')
